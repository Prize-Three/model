# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/밸류업 프로젝트(24 여름)/재검토0707/model_From_HF
# Out:
# /content/drive/MyDrive/밸류업 프로젝트(24 여름)/재검토0707/model_From_HF

# %% [markdown]
# ### HF TO SNAPSHOT

# %%
from huggingface_hub import snapshot_download
# # 불러올 허깅페이스모델 (model_id 변수에 할당)
model_id="sangthree/0707"
# # 현재 폴더 기준 폴더 생성
snapshot_download(repo_id=model_id, local_dir="0703modelFromHF",
                           local_dir_use_symlinks=False, revision="main")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1194: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
# ...

# %%
# Setup Llama.cpp and install required packages
#허깅페이스의 모델을 gguf로 변환하는 프로그램 다운로드
#구글 드라이브에 이미 있으면 두 번 실행할 필요 없음
# !git clone https://github.com/ggerganov/llama.cpp
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 29021, done.
# remote: Counting objects: 100% (6373/6373), done.
# remote: Compressing objects: 100% (508/508), done.
# remote: Total 29021 (delta 6097), reused 5933 (delta 5855), pack-reused 22648
# Receiving objects: 100% (29021/29021), 49.62 MiB | 14.79 MiB/s, done.
# Resolving deltas: 100% (20841/20841), done.
# Updating files: 100% (871/871), done.

# %%
#구글 드라이브에 이미 있으면 두 번 실행할 필요 없음
# !cd llama.cpp && LLAMA_CUBLAS=1 make
# Out:
# Makefile:72: *** LLAMA_CUBLAS is removed. Use GGML_CUDA instead..  Stop.

# %%
# !cd llama.cpp && GGML_CUDA=1 make
# Out:
# I ccache not found. Consider installing it for faster compilation.
# I llama.cpp build info:
# I UNAME_S:   Linux
# I UNAME_P:   x86_64
# I UNAME_M:   x86_64
# I CFLAGS:    -Iggml/include -Iggml/src -Iinclude -Isrc -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_OPENMP -DGGML_USE_LLAMAFILE -DGGML_USE_CUDA -I/usr/local/cuda/include -I/usr/local/cuda/targets/x86_64-linux/include -DGGML_CUDA_USE_GRAPHS  -std=c11   -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -Werror=implicit-function-declaration -pthread -march=native -mtune=native -fopenmp -Wdouble-promotion
# ...

# %%
# !pip install -r llama.cpp/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 52.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 39.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/Colab Notebooks/llama/05. Convert_HF_GGUF'

# %%
# !python llama.cpp/convert_hf_to_gguf.py 0703modelFromHF --outfile 0703modelFromHF.gguf --outtype f16
# Out:
# INFO:hf-to-gguf:Loading model: 0703modelFromHF
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Set model parameters
# INFO:hf-to-gguf:gguf: context length = 8192
# INFO:hf-to-gguf:gguf: embedding length = 4096
# INFO:hf-to-gguf:gguf: feed forward length = 14336
# INFO:hf-to-gguf:gguf: head count = 32
# INFO:hf-to-gguf:gguf: key-value head count = 8
# INFO:hf-to-gguf:gguf: rope theta = 500000.0
# INFO:hf-to-gguf:gguf: rms norm epsilon = 1e-05
# INFO:hf-to-gguf:gguf: file type = 1
# INFO:hf-to-gguf:Set model tokenizer
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# INFO:gguf.vocab:Adding 280147 merge(s).
# ...

# %%
import  huggingface_hub
huggingface_hub.login()

# %%
from huggingface_hub import HfApi
api = HfApi()

# gguf 파일 경로
file_path = "/content/drive/MyDrive/밸류업 프로젝트(24 여름)/재검토0707/model_From_HF/0703modelFromHF.gguf"

# Hugging Face 저장소 이름
repo_name = "sangthree/0707_gguf"

# 파일 업로드
api.upload_file(
    path_or_fileobj=file_path,
    path_in_repo="0703modelFromHF.gguf",  # 저장소 내 파일 경로
    repo_id=repo_name,
    repo_type="model",  # 모델 저장소에 업로드
)
# Out:
# 0703modelFromHF.gguf:   0%|          | 0.00/16.1G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/sangthree/0707_gguf/commit/7c8fe1f5a304ffd7a4f0b5c0f529cc3bd366b674', commit_message='Upload 0703modelFromHF.gguf with huggingface_hub', commit_description='', oid='7c8fe1f5a304ffd7a4f0b5c0f529cc3bd366b674', pr_url=None, pr_revision=None, pr_num=None)

# %%
# !python llama.cpp/convert-hf-to-gguf.py phi2 --outfile "phi2/phi2-v2-fp16.bin" --outtype f16

# %%
# llama-cpp-python 라이브러리가 GPU 가속을 위해 cuBLAS 라이브러리를 사용하도록 설정
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" pip install llama-cpp-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 MB 32.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 6.7 MB/s eta 0:00:00
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.2.76-cp310-cp310-linux_x86_64.whl size=80943104 sha256=9a49578ca823c7556c30a4108d5726d570d367fa3257587191e35bbeb34f6085
#   Stored in directory: /root/.cache/pip/wheels/a0/e5/04/a5fa9e60033548f205f0db5f6ab6f59cd27bd0da7f9c51cfe7
# Successfully built llama-cpp-python
# ...

# %%
from huggingface_hub import hf_hub_download
from llama_cpp import Llama

# %%
model_name = "hyokwan/llama3-ko-8b-hkcode"
model_file = "llama3-ko-8b-hkcode.gguf"
model_path = hf_hub_download(model_name,
                             filename=model_file,
                             local_dir="llama3_hkcode_gguf")
print("My model path: ", model_path)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     303     try:
# --> 304         response.raise_for_status()
#     305     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/hyokwan/llama3-ko-8b-hkcode/resolve/main/llama3-ko-8b-hkcode.gguf
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# <ipython-input-5-97684d2f4cc9> in <cell line: 3>()
#       1 model_name = "hyokwan/llama3-ko-8b-hkcode"
# ...

# %%
llm = Llama(model_path=model_path,
            n_gpu_layers=-1)

# %%
response = llm("스마트금융과는 어디에 위치하나요?", max_tokens=200)
response
